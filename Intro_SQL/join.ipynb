# %%
from google.cloud import bigquery

# %%
client = bigquery.Client()
dataset_ref = client.dataset("github_repos", project="bigquery-public-data")
dataset = client.get_dataset(dataset_ref)

license_ref = dataset_ref.table("licenses")
license_table = client.get_table(license_ref)

client.list_rows(license_table, max_results=5).to_dataframe()
# Out:
#                        repo_name       license
# 0  azuredream/chat_server-client  artistic-2.0
# 1            Egyptian19/JemCraft  artistic-2.0
# 2                  ZioRiP/cookie  artistic-2.0
# 3                  ajs/perl6-log  artistic-2.0
# 4        JohanPotgieter/Internet  artistic-2.0

# %%
files_ref = dataset_ref.table("sample_files")
files_table = client.get_table(files_ref)

client.list_rows(files_table, max_results=5).to_dataframe()
# Out:
#   repo_name                ref  \
# 0   git/git  refs/heads/master
# 1   np/ling  refs/heads/master
# 2   np/ling  refs/heads/master
# 3   np/ling  refs/heads/master
# 4   np/ling  refs/heads/master
#
#                                                 path   mode  \
# 0                                           RelNotes  40960
# 1       tests/success/plug_compose.t/plug_compose.ll  40960
# 2  fixtures/strict-par-success/parallel_assoc_lef...  40960
# 3  fixtures/sequence/parallel_assoc_2tensor2_left.ll  40960
# 4                        fixtures/success/my_dual.ll  40960
#
#                                          id  \
# 0  62615ffa4e97803da96aefbc798ab50f949a8db7
# 1  0c1605e4b447158085656487dc477f7670c4bac1
# 2  b59bff84ec03d12fabd3b51a27ed7e39a180097e
# 3  f29523e3fb65702d99478e429eac6f801f32152b
# 4  38a3af095088f90dfc956cb990e893909c3ab286
#
#                            symlink_target
# 0       Documentation/RelNotes/2.10.0.txt
# 1   ../../../fixtures/all/plug_compose.ll
# 2           ../all/parallel_assoc_left.ll
# 3  ../all/parallel_assoc_2tensor2_left.ll
# 4                       ../all/my_dual.ll

# %%
query1 = """
        SELECT L.license, COUNT(1) AS number_of_files
        FROM `bigquery-public-data.github_repos.sample_files` AS sf
        INNER JOIN `bigquery-public-data.github_repos.licenses` AS L
                ON sf.repo_name = L.repo_name
        GROUP BY L.license
        ORDER BY number_of_files DESC
        """

# %%
safe_config = bigquery.QueryJobConfig(maximum_bytes_billed = 10**10)

def get_query(my_query):
    my_query_job = client.query(my_query, job_config=safe_config)
    my_query_res = my_query_job.to_dataframe()
    return my_query_res

# %%
my_res = get_query(query1)
my_res
# Out:
#          license  number_of_files
# 0            mit         20432844
# 1        gpl-2.0         16867410
# 2     apache-2.0          7123968
# 3        gpl-3.0          4936531
# 4   bsd-3-clause          2943900
# 5       agpl-3.0          1293773
# 6       lgpl-2.1           793054
# 7   bsd-2-clause           694767
# 8       lgpl-3.0           564433
# 9        mpl-2.0           473078
# 10       cc0-1.0           405925
# 11       epl-1.0           320203
# 12     unlicense           208912
# 13  artistic-2.0           148414
# 14           isc           117709

# %% [markdown]
# ## Exercise

# %%
dataset_ref = client.dataset("stackoverflow", project='bigquery-public-data')
dataset = client.get_dataset(dataset_ref)

# %%
table_list = [i.table_id for i in client.list_tables(dataset)]
table_list
# Out:
# ['badges',
#  'comments',
#  'post_history',
#  'post_links',
#  'posts_answers',
#  'posts_moderator_nomination',
#  'posts_orphaned_tag_wiki',
#  'posts_privilege_wiki',
#  'posts_questions',
#  'posts_tag_wiki',
#  'posts_tag_wiki_excerpt',
#  'posts_wiki_placeholder',
#  'stackoverflow_posts',
#  'tags',
#  'users',
#  'votes']

# %%
answers_table_ref = dataset_ref.table("posts_answers")
answers_table = client.get_table(answers_table_ref)
client.list_rows(answers_table, max_results=5).to_dataframe()
# Out:
#          id title                                               body  \
# 0  58545647  None  <p>You can implement the <a href="https://docs...
# 1  58545649  None  <p>You may be having an issue with the "stage"...
# 2  58545664  None  <p>I am not sure why you need that exactly but...
# 3  58545675  None  <pre><code>Object delegateObj = readField(valu...
# 4  58545677  None  <p>I had to remove the line</p>\n\n<pre><code>...
#
#   accepted_answer_id answer_count  comment_count community_owned_date  \
# 0               None         None              0                 None
# 1               None         None              0                 None
# 2               None         None              0                 None
# 3               None         None              1                 None
# 4               None         None              0                 None
#
#                      creation_date favorite_count  \
# 0 2019-10-24 16:35:51.947000+00:00           None
# 1 2019-10-24 16:35:59.377000+00:00           None
# 2 2019-10-24 16:36:39.870000+00:00           None
# 3 2019-10-24 16:37:20.207000+00:00           None
# 4 2019-10-24 16:37:51.253000+00:00           None
#
#                 last_activity_date last_edit_date last_editor_display_name  \
# 0 2019-10-24 16:35:51.947000+00:00           None                     None
# 1 2019-10-24 16:35:59.377000+00:00           None                     None
# 2 2019-10-24 16:36:39.870000+00:00           None                     None
# 3 2019-10-24 16:37:20.207000+00:00           None                     None
# 4 2019-10-24 16:37:51.253000+00:00           None                     None
#
#   last_editor_user_id owner_display_name  owner_user_id  parent_id  \
# 0                None               None        2541560   58545487
# 1                None               None        4434749   56565949
# 2                None               None        8343843   58545068
# 3                None               None       12269981   57195785
# 4                None               None        1775258   58428566
#
#    post_type_id  score  tags view_count
# 0             2      0  None       None
# 1             2      0  None       None
# 2             2      0  None       None
# 3             2      0  None       None
# 4             2      0  None       None

# %%
questions_table_ref = dataset_ref.table("posts_questions")
questions_table = client.get_table(questions_table_ref)
client.list_rows(questions_table, max_results=5).to_dataframe()
# Out:
#          id                                              title  \
# 0  31098630  IntelliJ IDEA - JPanel in JScrollpane no conte...
# 1  31102757  SDL2: I Receive Segmentation Fault on Line 5, ...
# 2  31104792   angularjs with nodejs the ng-repeat doesn´t work
# 3  31106810  How to know the cache line of A8 chip is 64 by...
# 4  31112648                            Projection by interface
#
#                                                 body  accepted_answer_id  \
# 0  <p><br>\nI have a JScrollPane which needs to b...                 NaN
# 1  <p>When I run the program I get a segmentation...                 NaN
# 2  <p>This is my angular code <a href="http://pas...          31104833.0
# 3  <p>How the get the information of the apple ch...          31154387.0
# 4  <p>I'm wondering what's the best way to perfor...                 NaN
#
#    answer_count  comment_count community_owned_date  \
# 0             1              0                 None
# 1             1              0                 None
# 2             1              0                 None
# 3             1              0                 None
# 4             1              0                 None
#
#                      creation_date favorite_count  \
# 0 2015-06-28 10:18:28.330000+00:00           None
# 1 2015-06-28 17:40:02.090000+00:00           None
# 2 2015-06-28 21:10:19.913000+00:00           None
# 3 2015-06-29 02:11:34.657000+00:00           None
# 4 2015-06-29 09:53:48.253000+00:00           None
#
#                 last_activity_date                   last_edit_date  \
# 0 2015-06-28 11:21:40.713000+00:00                              NaT
# 1 2015-07-01 10:04:04.650000+00:00 2015-07-01 10:03:25.343000+00:00
# 2 2015-06-28 21:15:17.693000+00:00                              NaT
# 3 2015-07-01 06:50:46.390000+00:00 2015-06-29 02:13:57.387000+00:00
# 4 2015-06-29 10:25:17.367000+00:00 2015-06-29 10:15:04.637000+00:00
#
#   last_editor_display_name  last_editor_user_id owner_display_name  \
# 0                     None                  NaN               None
# 1                     None            2564301.0               None
# 2                     None                  NaN               None
# 3                     None              87197.0               None
# 4                     None            1501208.0               None
#
#    owner_user_id parent_id  post_type_id  score  \
# 0        4314870      None             1      0
# 1        4969570      None             1     -2
# 2        5059050      None             1      0
# 3        1468120      None             1      0
# 4         498298      None             1      2
#
#                                     tags  view_count
# 0        java|swing|intellij-idea|jframe         256
# 1                    c++|c|gcc|sdl|sdl-2         256
# 2  angularjs|node.js|socket.io|ng-repeat         256
# 3                          ios|processor         256
# 4         c#|mongodb|mongodb-.net-driver         256

# %%
safe_config = bigquery.QueryJobConfig(maximum_bytes_billed= 10**10)

# %%
questions_query = """
                SELECT id, title, owner_user_id
                FROM `bigquery-public-data.stackoverflow.posts_questions`
                WHERE tags LIKE '%bigquery%'
                """
questions_query_ans = get_query(questions_query)
questions_query_ans.head()
# Out:
#          id                                              title  owner_user_id
# 0  31255937                    Bigquery Free Trial limitations      5084442.0
# 1  31464373  Trouble Looking For Events WITHIN a Session In...      2114472.0
# 2  31240582  bq show cames to return no Total Rows and Tota...      5084312.0
# 3  31526966  Semijoin expression must be a part of logical AND      2800623.0
# 4  31319016             How to get Day name in Google BigQuery      4961403.0

# %%
query_2 = """
        SELECT a.id, a.body, a.owner_user_id
        FROM `bigquery-public-data.stackoverflow.posts_questions` as q
        INNER JOIN `bigquery-public-data.stackoverflow.posts_answers` as a
            ON q.id = a.parent_id
        WHERE q.tags LIKE '%bigquery%'
        """

query_ans_2 = get_query(query_2)
query_ans_2.head()
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# <ipython-input-21-835a9fe51137> in <module>
#       7         """
#       8
# ----> 9 query_ans_2 = get_query(query_2)
#      10 query_ans_2.head()
#
# <ipython-input-6-012aa9963e05> in get_query(my_query)
#       3 def get_query(my_query):
#       4     my_query_job = client.query(my_query, job_config=safe_config)
# ----> 5     my_query_res = my_query_job.to_dataframe()
#       6     return my_query_res
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/job.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client)
#    3368             ValueError: If the `pandas` library cannot be imported.
#    3369         """
# -> 3370         return self.result().to_dataframe(
#    3371             bqstorage_client=bqstorage_client,
#    3372             dtypes=dtypes,
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/job.py in result(self, page_size, max_results, retry, timeout)
#    3194             )
#    3195             with guard:
# -> 3196                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    3197             timeout = guard.remaining_timeout
#    3198
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/job.py in result(self, retry, timeout)
#     816             timeout = guard.remaining_timeout
#     817         # TODO: modify PollingFuture so it can pass a retry argument to done().
# --> 818         return super(_AsyncJob, self).result(timeout=timeout)
#     819
#     820     def cancelled(self):
#
# ~/anaconda3/lib/python3.7/site-packages/google/api_core/future/polling.py in result(self, timeout)
#     120                 the timeout is reached before the operation completes.
#     121         """
# --> 122         self._blocking_poll(timeout=timeout)
#     123
#     124         if self._exception is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/job.py in _blocking_poll(self, timeout)
#    3096     def _blocking_poll(self, timeout=None):
#    3097         self._done_timeout = timeout
# -> 3098         super(QueryJob, self)._blocking_poll(timeout=timeout)
#    3099
#    3100     @staticmethod
#
# ~/anaconda3/lib/python3.7/site-packages/google/api_core/future/polling.py in _blocking_poll(self, timeout)
#      99
#     100         try:
# --> 101             retry_(self._done_or_raise)()
#     102         except exceptions.RetryError:
#     103             raise concurrent.futures.TimeoutError(
#
# ~/anaconda3/lib/python3.7/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     284                 sleep_generator,
#     285                 self._deadline,
# --> 286                 on_error=on_error,
#     287             )
#     288
#
# ~/anaconda3/lib/python3.7/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     182     for sleep in sleep_generator:
#     183         try:
# --> 184             return target()
#     185
#     186         # pylint: disable=broad-except
#
# ~/anaconda3/lib/python3.7/site-packages/google/api_core/future/polling.py in _done_or_raise(self)
#      78     def _done_or_raise(self):
#      79         """Check if the future is done and raise if it's not."""
# ---> 80         if not self.done():
#      81             raise _OperationNotComplete()
#      82
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/job.py in done(self, retry, timeout)
#    3083                 timeout_ms=timeout_ms,
#    3084                 location=self.location,
# -> 3085                 timeout=timeout,
#    3086             )
#    3087
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/client.py in _get_query_results(self, job_id, retry, project, timeout_ms, location, timeout)
#    1285         # QueryJob.result()). So we don't need to poll here.
#    1286         resource = self._call_api(
# -> 1287             retry, method="GET", path=path, query_params=extra_params, timeout=timeout
#    1288         )
#    1289         return _QueryResults.from_api_repr(resource)
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/client.py in _call_api(self, retry, **kwargs)
#     554         if retry:
#     555             call = retry(call)
# --> 556         return call()
#     557
#     558     def get_dataset(self, dataset_ref, retry=DEFAULT_RETRY, timeout=None):
#
# ~/anaconda3/lib/python3.7/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     284                 sleep_generator,
#     285                 self._deadline,
# --> 286                 on_error=on_error,
#     287             )
#     288
#
# ~/anaconda3/lib/python3.7/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     182     for sleep in sleep_generator:
#     183         try:
# --> 184             return target()
#     185
#     186         # pylint: disable=broad-except
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/_http.py in api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout)
#     421
#     422         if not 200 <= response.status_code < 300:
# --> 423             raise exceptions.from_http_response(response)
#     424
#     425         if expect_json and response.content:
#
# BadRequest: 400 GET https://bigquery.googleapis.com/bigquery/v2/projects/kaggle-project-271505/queries/27c983c6-c0be-437f-9b2a-ee411806fc27?maxResults=0&location=US: Query exceeded limit for bytes billed: 10000000000. 23881318400 or higher required.
#
# (job ID: 27c983c6-c0be-437f-9b2a-ee411806fc27)
#
#                         -----Query Job SQL Follows-----
#
#     |    .    |    .    |    .    |    .    |    .    |    .    |    .    |
#    1:
#    2:        SELECT a.id, a.body, a.owner_user_id
#    3:        FROM `bigquery-public-data.stackoverflow.posts_questions` as q
#    4:        INNER JOIN `bigquery-public-data.stackoverflow.posts_answers` as a
#    5:            ON q.id = a.parent_id
#    6:        WHERE q.tags LIKE '%bigquery%'
#    7:
#     |    .    |    .    |    .    |    .    |    .    |    .    |    .    |

# %%
answers_query = """
                SELECT a.id, a.body, a.owner_user_id
                FROM `bigquery-public-data.stackoverflow.posts_questions` AS q 
                INNER JOIN `bigquery-public-data.stackoverflow.posts_answers` AS a
                    ON q.id = a.parent_id
                WHERE q.tags LIKE '%bigquery%'
                """
# Set up the query
safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=10**10)
answers_query_job = client.query(answers_query, job_config=safe_config) # Your code goes here

# API request - run the query, and return a pandas DataFrame
answers_results = answers_query_job.to_dataframe()# Your code goes here

# Preview results
print(answers_results.head())
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# <ipython-input-25-fea025ba0c6b> in <module>
#      11
#      12 # API request - run the query, and return a pandas DataFrame
# ---> 13 answers_results = answers_query_job.to_dataframe()# Your code goes here
#      14
#      15 # Preview results
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/job.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client)
#    3368             ValueError: If the `pandas` library cannot be imported.
#    3369         """
# -> 3370         return self.result().to_dataframe(
#    3371             bqstorage_client=bqstorage_client,
#    3372             dtypes=dtypes,
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/job.py in result(self, page_size, max_results, retry, timeout)
#    3194             )
#    3195             with guard:
# -> 3196                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    3197             timeout = guard.remaining_timeout
#    3198
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/job.py in result(self, retry, timeout)
#     816             timeout = guard.remaining_timeout
#     817         # TODO: modify PollingFuture so it can pass a retry argument to done().
# --> 818         return super(_AsyncJob, self).result(timeout=timeout)
#     819
#     820     def cancelled(self):
#
# ~/anaconda3/lib/python3.7/site-packages/google/api_core/future/polling.py in result(self, timeout)
#     120                 the timeout is reached before the operation completes.
#     121         """
# --> 122         self._blocking_poll(timeout=timeout)
#     123
#     124         if self._exception is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/job.py in _blocking_poll(self, timeout)
#    3096     def _blocking_poll(self, timeout=None):
#    3097         self._done_timeout = timeout
# -> 3098         super(QueryJob, self)._blocking_poll(timeout=timeout)
#    3099
#    3100     @staticmethod
#
# ~/anaconda3/lib/python3.7/site-packages/google/api_core/future/polling.py in _blocking_poll(self, timeout)
#      99
#     100         try:
# --> 101             retry_(self._done_or_raise)()
#     102         except exceptions.RetryError:
#     103             raise concurrent.futures.TimeoutError(
#
# ~/anaconda3/lib/python3.7/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     284                 sleep_generator,
#     285                 self._deadline,
# --> 286                 on_error=on_error,
#     287             )
#     288
#
# ~/anaconda3/lib/python3.7/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     182     for sleep in sleep_generator:
#     183         try:
# --> 184             return target()
#     185
#     186         # pylint: disable=broad-except
#
# ~/anaconda3/lib/python3.7/site-packages/google/api_core/future/polling.py in _done_or_raise(self)
#      78     def _done_or_raise(self):
#      79         """Check if the future is done and raise if it's not."""
# ---> 80         if not self.done():
#      81             raise _OperationNotComplete()
#      82
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/job.py in done(self, retry, timeout)
#    3083                 timeout_ms=timeout_ms,
#    3084                 location=self.location,
# -> 3085                 timeout=timeout,
#    3086             )
#    3087
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/client.py in _get_query_results(self, job_id, retry, project, timeout_ms, location, timeout)
#    1285         # QueryJob.result()). So we don't need to poll here.
#    1286         resource = self._call_api(
# -> 1287             retry, method="GET", path=path, query_params=extra_params, timeout=timeout
#    1288         )
#    1289         return _QueryResults.from_api_repr(resource)
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/client.py in _call_api(self, retry, **kwargs)
#     554         if retry:
#     555             call = retry(call)
# --> 556         return call()
#     557
#     558     def get_dataset(self, dataset_ref, retry=DEFAULT_RETRY, timeout=None):
#
# ~/anaconda3/lib/python3.7/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     284                 sleep_generator,
#     285                 self._deadline,
# --> 286                 on_error=on_error,
#     287             )
#     288
#
# ~/anaconda3/lib/python3.7/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     182     for sleep in sleep_generator:
#     183         try:
# --> 184             return target()
#     185
#     186         # pylint: disable=broad-except
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/_http.py in api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout)
#     421
#     422         if not 200 <= response.status_code < 300:
# --> 423             raise exceptions.from_http_response(response)
#     424
#     425         if expect_json and response.content:
#
# BadRequest: 400 GET https://bigquery.googleapis.com/bigquery/v2/projects/kaggle-project-271505/queries/2ed3e0fd-c230-481a-83ad-16537b3c37cc?maxResults=0&location=US: Query exceeded limit for bytes billed: 10000000000. 23881318400 or higher required.
#
# (job ID: 2ed3e0fd-c230-481a-83ad-16537b3c37cc)
#
#                             -----Query Job SQL Follows-----
#
#     |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |
#    1:
#    2:                SELECT a.id, a.body, a.owner_user_id
#    3:                FROM `bigquery-public-data.stackoverflow.posts_questions` AS q
#    4:                INNER JOIN `bigquery-public-data.stackoverflow.posts_answers` AS a
#    5:                    ON q.id = a.parent_id
#    6:                WHERE q.tags LIKE '%bigquery%'
#    7:
#     |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |

# %%
topic = 'bigquery'
bigquery_experts_query = """
                SELECT a.owner_user_id AS user_id, COUNT(1) AS number_of_answers
                FROM `bigquery-public-data.stackoverflow.posts_questions` AS q 
                INNER JOIN `bigquery-public-data.stackoverflow.posts_answers` AS a
                    ON q.id = a.parent_id
                WHERE q.tags CONTAINS @topic
                GROUP BY user_id
                """

bigquery_experts_ans = get_query(bigquery_experts_query)
bigquery_experts_ans.head()
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# <ipython-input-47-6666bc5511e6> in <module>
#       9                 """
#      10
# ---> 11 bigquery_experts_ans = get_query(bigquery_experts_query)
#      12 bigquery_experts_ans.head()
#
# <ipython-input-6-012aa9963e05> in get_query(my_query)
#       3 def get_query(my_query):
#       4     my_query_job = client.query(my_query, job_config=safe_config)
# ----> 5     my_query_res = my_query_job.to_dataframe()
#       6     return my_query_res
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/job.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client)
#    3368             ValueError: If the `pandas` library cannot be imported.
#    3369         """
# -> 3370         return self.result().to_dataframe(
#    3371             bqstorage_client=bqstorage_client,
#    3372             dtypes=dtypes,
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/job.py in result(self, page_size, max_results, retry, timeout)
#    3194             )
#    3195             with guard:
# -> 3196                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    3197             timeout = guard.remaining_timeout
#    3198
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/job.py in result(self, retry, timeout)
#     816             timeout = guard.remaining_timeout
#     817         # TODO: modify PollingFuture so it can pass a retry argument to done().
# --> 818         return super(_AsyncJob, self).result(timeout=timeout)
#     819
#     820     def cancelled(self):
#
# ~/anaconda3/lib/python3.7/site-packages/google/api_core/future/polling.py in result(self, timeout)
#     125             # pylint: disable=raising-bad-type
#     126             # Pylint doesn't recognize that this is valid in this case.
# --> 127             raise self._exception
#     128
#     129         return self._result
#
# BadRequest: 400 Syntax error: Unexpected keyword CONTAINS at [6:30]
#
# (job ID: 9d2b6acb-cc22-45b9-a49a-6debbeb6713c)
#
#                             -----Query Job SQL Follows-----
#
#     |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |
#    1:
#    2:                SELECT a.owner_user_id AS user_id, COUNT(1) AS number_of_answers
#    3:                FROM `bigquery-public-data.stackoverflow.posts_questions` AS q
#    4:                INNER JOIN `bigquery-public-data.stackoverflow.posts_answers` AS a
#    5:                    ON q.id = a.parent_id
#    6:                WHERE q.tags CONTAINS @topic
#    7:                GROUP BY user_id
#    8:
#     |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |

# %%
def expert_finder(topic, my_client):
    my_expert_query = """
                    SELECT a.owner_user_id AS user_id, COUNT(1) AS number_of_answers
                    FROM `bigquery-public-data.stackoverflow.posts_questions` AS q 
                    INNER JOIN `bigquery-public-data.stackoverflow.posts_answers` AS a
                        ON q.id = a.parent_id
                    WHERE q.tags LIKE '%@topic%'
                    GROUP BY a.owner_user_id
                    """    
    
    safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=10**10)
    my_query_job = my_client.query(my_expert_query, job_config=safe_config)
    my_ans = my_query_job.to_dataframe()
    return my_ans

# %%
my_topic = "bigquery"
my_ans = expert_finder(my_topic, client)
my_ans.head()
# Out:
# Empty DataFrame
# Columns: [user_id, number_of_answers]
# Index: []
